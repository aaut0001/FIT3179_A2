# %% [markdown]
# # Data Wrangling and Pre-processing
#
# this file will download the csv of airline dataset and then add the longitude and latitude for each airport

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./my_venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./my_venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./my_venv/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./my_venv/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in ./my_venv/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in ./my_venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd 

data = pd.read_csv("Airline Dataset.csv")
data
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 98614                EU         Europe     12/11/2022             HAA
# 98615                AF         Africa     10/30/2022             IVA
# 98616                EU         Europe      9/10/2022             ABC
# 98617                AF         Africa     10/26/2022             GGN
# 98618                EU         Europe      4/16/2022             JOK
#
#               Pilot Name Flight Status
# 0          Edithe Leggis       On Time
# 1            Elwood Catt       On Time
# 2          Darby Felgate       On Time
# 3          Dominica Pyle       Delayed
# 4            Bay Pencost       On Time
# ...                  ...           ...
# 98614     Gareth Mugford     Cancelled
# 98615     Kasey Benedict     Cancelled
# 98616      Darrin Lucken       On Time
# 98617    Gayle Lievesley     Cancelled
# 98618  Wilhelmine Touret       Delayed
#
# [98619 rows x 15 columns]

# %% [markdown]
# # Airport locations
#
# reading the airports.dat file and converting it to a pandas dataframe
#
# As the stucture has commas inside some of the fields, have to use regular expression to read it in
# - import re

# %%
# import re
import re

# open the airports.dat file
with open("airports.dat", "r", encoding="utf-8") as file:
    lines = file.readlines()

airport_data = [re.split(r',(?=(?:[^"]*"[^"]*")*[^"]*$)', line.strip()) for line in lines]
airports_df = pd.DataFrame(airport_data, 
                           columns=[
                               "ID", 
                               "Name", 
                               "City", 
                               "Country", 
                               "IATA", 
                               "ICAO", 
                               "Latitude", 
                               "Longitude", 
                               "Elevation", 
                               "Timezone", 
                               "DST", 
                               "TzDatabase", 
                               "Type", 
                               "Source"])

# rename the columns
airports_df = airports_df.rename(columns={"Name": "Airport Name", 
                                          "Country": "Airport Country Code",
                                          "City": "Airport City"})

# convert coordinates to numeric form
airports_df["Latitude"] = pd.to_numeric(airports_df["Latitude"])
airports_df["Longitude"] = pd.to_numeric(airports_df["Longitude"])

# get the columns i need: Airport Name, Airport Country Code, Latitude, Longitude
airports_df = airports_df[["Airport Name", "Latitude", "Longitude"]]
airports_df["Airport Name"] = airports_df["Airport Name"].str.replace('"', '')
print(airports_df.shape)

airports_df.head(5)
# Out:
# (7698, 3)
#                                   Airport Name  Latitude   Longitude
# 0                               Goroka Airport -6.081690  145.391998
# 1                               Madang Airport -5.207080  145.789001
# 2                 Mount Hagen Kagamuga Airport -5.826790  144.296005
# 3                               Nadzab Airport -6.569803  146.725977
# 4  Port Moresby Jacksons International Airport -9.443380  147.220001

# %% [markdown]
# # Merging
#
# To merge,
# - first check for unmatching airport names.
# - merge on left and right with left join

# %%
non_matching_airports = set(data["Airport Name"]) - set(airports_df["Airport Name"])
if non_matching_airports:
    print("Airport names in current data that dont match:")
    print(non_matching_airports)
    print(len(non_matching_airports))
else:
    print("All airport names match")
# Out:
# Airport names in current data that dont match:
# {'Ogeranang Airport', 'Leron Plains Airport', 'Colinas Airport', 'Walter J. Koladza Airport', 'Anthony Lagoon Airport', 'Humboldt Municipal Airport', 'Itabuna Airport', 'Iaciara Airport', 'Bongo Airport', 'LBJ Ranch Airport', 'Bernay – St Martin Airport', 'Virginia Highlands Airport', 'Grand Canyon West Airport', 'Agostinho Neto Airport', 'Erdenet Airport', 'Marion County Rankin Fite Airport', 'Weam Airport', 'Kitava Airport', 'Carmelita Airport', 'Baytown Airport', 'El Charco Airport', 'Gardner Municipal Airport', 'Nowata Airport', 'Holešov Airport', 'Augustus Downs Airport', 'Leitre Airport', 'Ouadda Airport', 'Thakhek Airport', 'San Ignacio Airport', 'Torokina Airport', 'Nutwood Downs Airport', 'Carlos Ruhl Airport', 'Searle Field', 'Semporna Airport', 'Gordon Downs Airport', 'Moanda Airport', 'Sullivan County International Airport', 'Koinambe Airport', 'Frieda River Airport', 'El Refugio/La Macarena Airport', 'Marigot Seaplane Base', 'El Naranjo Airport', 'Sulaco Airport', 'Tambao Airport', 'Puerto Berrio Airport', 'Chernofski Harbor Seaplane Base', 'Manetai Airport', 'Kornasoren Airfield', 'Gaoua Airport', 'Hólmavík Airport', 'Mount Sanford Station Airport', 'Porto de Moz Airport', 'Kamusi Airport', 'Ati Airport', 'Tingwon Airport', 'Balgo Hill Airport', 'Mayor PNP Nancy Flores Paucar Airport', 'Lunyuk Airport', 'Khan Jahan Ali Airport', 'False Island Seaplane Base', 'Szczecin-Goleniów "Solidarność" Airport', 'Louis Trichardt Airport', 'Komo-Manda Airport', 'Yuruf Airport', 'Kirk Field', 'Tol Airport', 'Heiweni Airport', 'Gold Beach Municipal Airport', 'Mostaganem Airport', 'Kaiapit Airport', 'Kuyol Airport', 'Pukapuka Island Airport', 'Paraguaçu Airport', 'Jaluit Airport', 'Marsabit Airport', 'Manono Airport', 'Bhurban Heliport', 'Naukati Bay Seaplane Base', 'Sungai Tiang Airport', 'Asirim Airport', 'Alberni Valley Regional Airport', 'Ouango Fitini Airport', 'Gulgubip Airport', 'Myrhorod Air Base', 'Vejrø', 'Eaker Field', 'Booue Airport', 'Debepare Airport', 'Lemwerder Airport', 'Mangunjaya Airport', 'Crookston Municipal Kirkwood Field', 'Gwa Airport', 'Fazenda São João Airport', 'Tangalooma Airport', 'Buriti Alegre Airport', 'Monkira Airport', 'San Luis De Palenque Airport', 'Pretoria Central Heliport', 'Mid-Carolina Regional Airport', 'Þingeyri Airport', 'Entrance Island Seaplane Base', 'Puas Airport', 'Mulga Park Airport', 'Cauquira Airport', 'Margaret River (Station) Airport', 'Sharpe Field', 'Camfield Airport', 'Hpapun Airport', 'Amchitka Army Airfield', 'Presidente Venceslau Airport', 'Bella Bella (Campbell Island) Airport', 'Orange Walk Airport', 'Lava Falls Heliport', 'Kaoh Kong Airport', 'Gurue Airport', 'West Angelas Airport', 'Taguatinga Airport', 'Wave Hill Airport', 'Hemet Ryan Airport', 'Tobolsk Airport', 'Basongo Airport', 'Mejit Atoll Airport', 'Garaina Airport', 'Cape Orford Airport', 'Deer Park Airport', 'Noto Hadinegoro, Jember Airport', 'Daporijo Airport', 'Merrill Municipal Airport', 'Puerto Armuelles Airport', 'Geladi Airport', 'Chicken Airport', 'Banaina Airport', 'Jutigalpa airport', 'Zabreh Ostrava Airport', 'Pweto Airport', 'Maloelap Island Airport', 'Susanville Municipal Airport', 'Varandey Airport', 'Sheep Mountain Airport', 'Plastun Airport', 'Tokoroa Airfield', 'El Petén Airport', 'Monticello Airport', 'Tanque Novo Airport', 'New Amsterdam Airport', "Les Sables-d'Olonne Talmont Airport", 'Mount Swan Airport', 'Maquinchao Airport', 'Singita Safari Lodge Airport', 'Big Lake Airport', 'Wuvulu Island Airport', 'Mindik Airport', 'Miyanmin Airport', 'El Minya Airport', 'Yangambi Airport', 'Pureni Airport', 'Sipitang Airport', 'Chilko Lake (Tsylos Park Lodge) Airport', 'Billiluna Airport', 'Chatham Seaplane Base', 'Muttaburra Airport', 'Caledonia County Airport', 'Tioga Municipal Airport', 'Edna Bay Seaplane Base', 'May Creek Airport', 'Cordillo Downs Airport', 'Kiryat Shmona Airport', 'Greater Southwest International Airport-Amon Carter Field', 'Cururupu Airport', 'Naval Outlying Field Imperial Be ...
# 3049

# %%
# merge on airport names that do match
merged_data = pd.merge(data, airports_df, on="Airport Name", how="left")
merged_data
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 99438         58454      Gareth    Mugford    Male   85       China
# 99439         22028       Kasey   Benedict  Female   19      Russia
# 99440         61732      Darrin     Lucken    Male   65   Indonesia
# 99441         19819       Gayle  Lievesley  Female   34       China
# 99442         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 99438               Hasvik Airport                   NO              Norway
# 99439          Ampampamena Airport                   MG          Madagascar
# 99440  Albacete-Los Llanos Airport                   ES               Spain
# 99441               Gagnoa Airport                   CI       Côte d'Ivoire
# 99442          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 99438                EU         Europe     12/11/2022             HAA
# 99439                AF         Africa     10/30/2022             IVA
# 99440                EU         Europe      9/10/2022             ABC
# 99441                AF         Africa     10/26/2022             GGN
# 99442                EU         Europe      4/16/2022             JOK
#
#               Pilot Name Flight Status   Latitude   Longitude
# 0          Edithe Leggis       On Time        NaN         NaN
# 1            Elwood Catt       On Time  67.816704 -115.143997
# 2          Darby Felgate       On Time  45.362900    5.329370
# 3          Dominica Pyle       Delayed  45.521702  -75.563599
# 4            Bay Pencost       On Time  32.826199 -116.972000
# ...                  ...           ...        ...         ...
# 99438     Gareth Mugford     Cancelled  70.486702   22.139700
# 99439     Kasey Benedict     Cancelled -13.484816   48.632702
# 99440      Darrin Lucken       On Time  38.948502   -1.863520
# 99441    Gayle Lievesley     Cancelled        NaN         NaN
# 99442  Wilhelmine Touret       Delayed  56.700600   47.904701
#
# [99443 rows x 17 columns]

# %% [markdown]
# # Cleaning Merged Data
#
# Now that the data has been merged, there are almost 100,000 rows of data so we need to clean up any locations that dont have Longitude or Latitude

# %%
merged_data = merged_data.dropna(subset=["Latitude", "Longitude"])
merged_data
# Out:
#        Passenger ID  First Name Last Name  Gender  Age Nationality  \
# 1             43872      Elwood      Catt    Male   62   Nicaragua
# 2             42633       Darby   Felgate    Male   67      Russia
# 3             78493    Dominica      Pyle  Female   71       China
# 4             82072         Bay   Pencost    Male   21       China
# 5             39630        Lora   Durbann  Female   55      Brazil
# ...             ...         ...       ...     ...  ...         ...
# 99433         70741     Olimpia   Arstall  Female   22       China
# 99438         58454      Gareth   Mugford    Male   85       China
# 99439         22028       Kasey  Benedict  Female   19      Russia
# 99440         61732      Darrin    Lucken    Male   65   Indonesia
# 99442         14485  Wilhelmine    Touret  Female   10      Poland
#
#                             Airport Name Airport Country Code  \
# 1                      Kugluktuk Airport                   CA
# 2                 Grenoble-Isère Airport                   FR
# 3              Ottawa / Gatineau Airport                   CA
# 4                        Gillespie Field                   US
# 5      Coronel Horácio de Mattos Airport                   BR
# ...                                  ...                  ...
# 99433        Wuzhou Changzhoudao Airport                   CN
# 99438                     Hasvik Airport                   NO
# 99439                Ampampamena Airport                   MG
# 99440        Albacete-Los Llanos Airport                   ES
# 99442                Yoshkar-Ola Airport                   RU
#
#              Country Name Airport Continent     Continents Departure Date  \
# 1                  Canada               NAM  North America     12/26/2022
# 2                  France                EU         Europe      1/18/2022
# 3                  Canada               NAM  North America      9/16/2022
# 4           United States               NAM  North America      2/25/2022
# 5                  Brazil               SAM  South America      6/10/2022
# ...                   ...               ...            ...            ...
# 99433               China                AS           Asia      4/23/2022
# 99438              Norway                EU         Europe     12/11/2022
# 99439          Madagascar                AF         Africa     10/30/2022
# 99440               Spain                EU         Europe      9/10/2022
# 99442  Russian Federation                EU         Europe      4/16/2022
#
#       Arrival Airport         Pilot Name Flight Status   Latitude   Longitude
# 1                 YCO        Elwood Catt       On Time  67.816704 -115.143997
# 2                 GNB      Darby Felgate       On Time  45.362900    5.329370
# 3                 YND      Dominica Pyle       Delayed  45.521702  -75.563599
# 4                 SEE        Bay Pencost       On Time  32.826199 -116.972000
# 5                 LEC       Lora Durbann       On Time -12.482300  -41.277000
# ...               ...                ...           ...        ...         ...
# 99433             WUZ    Olimpia Arstall       On Time  23.456699  111.248001
# 99438             HAA     Gareth Mugford     Cancelled  70.486702   22.139700
# 99439             IVA     Kasey Benedict     Cancelled -13.484816   48.632702
# 99440             ABC      Darrin Lucken       On Time  38.948502   -1.863520
# 99442             JOK  Wilhelmine Touret       Delayed  56.700600   47.904701
#
# [66418 rows x 17 columns]

# %%
merged_data.to_json('airline.json', orient='records', lines = True)

# %%
airline_json = "airline.json"
df = pd.read_json(airline_json, lines=True)
csv_file = "airline.csv"
df.to_csv(csv_file, index=False)

# %% [markdown]
# # Airports and Freq
#
# below will be data wrangling.
# - airports
# - airports frequency
# - longitude and latitudes

# %%
df = pd.read_csv("airline.csv")

# group df by airport name and count occurrences
airport_counts = df["Airport Name"].value_counts().reset_index()

airport_counts.columns = ['Airport Name', 'Frequency']

# create new df
new_df = airport_counts.merge(df[['Airport Name', 'Latitude', 'Longitude']].drop_duplicates(), on="Airport Name")
new_df

new_df.to_csv("airport_info.csv", index=False)

# %% [markdown]
# # Data Wrangling and Pre-processing
#
# this file will download the csv of airline dataset and then add the longitude and latitude for each airport

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./my_venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./my_venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./my_venv/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./my_venv/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in ./my_venv/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in ./my_venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd 

data = pd.read_csv("Airline Dataset.csv")
data
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 98614                EU         Europe     12/11/2022             HAA
# 98615                AF         Africa     10/30/2022             IVA
# 98616                EU         Europe      9/10/2022             ABC
# 98617                AF         Africa     10/26/2022             GGN
# 98618                EU         Europe      4/16/2022             JOK
#
#               Pilot Name Flight Status
# 0          Edithe Leggis       On Time
# 1            Elwood Catt       On Time
# 2          Darby Felgate       On Time
# 3          Dominica Pyle       Delayed
# 4            Bay Pencost       On Time
# ...                  ...           ...
# 98614     Gareth Mugford     Cancelled
# 98615     Kasey Benedict     Cancelled
# 98616      Darrin Lucken       On Time
# 98617    Gayle Lievesley     Cancelled
# 98618  Wilhelmine Touret       Delayed
#
# [98619 rows x 15 columns]

# %% [markdown]
# # Airport locations
#
# reading the airports.dat file and converting it to a pandas dataframe
#
# As the stucture has commas inside some of the fields, have to use regular expression to read it in
# - import re

# %%
# import re
import re

# open the airports.dat file
with open("airports.dat", "r", encoding="utf-8") as file:
    lines = file.readlines()

airport_data = [re.split(r',(?=(?:[^"]*"[^"]*")*[^"]*$)', line.strip()) for line in lines]
airports_df = pd.DataFrame(airport_data, 
                           columns=[
                               "ID", 
                               "Name", 
                               "City", 
                               "Country", 
                               "IATA", 
                               "ICAO", 
                               "Latitude", 
                               "Longitude", 
                               "Elevation", 
                               "Timezone", 
                               "DST", 
                               "TzDatabase", 
                               "Type", 
                               "Source"])

# rename the columns
airports_df = airports_df.rename(columns={"Name": "Airport Name", 
                                          "Country": "Airport Country Code",
                                          "City": "Airport City"})

# convert coordinates to numeric form
airports_df["Latitude"] = pd.to_numeric(airports_df["Latitude"])
airports_df["Longitude"] = pd.to_numeric(airports_df["Longitude"])

# get the columns i need: Airport Name, Airport Country Code, Latitude, Longitude
airports_df = airports_df[["Airport Name", "Airport Country Code", "Latitude", "Longitude"]]
airports_df["Airport Name"] = airports_df["Airport Name"].str.replace('"', '')
airports_df["Airport Country Code"] = airports_df["Airport Country Code"].str.replace('"', '')
print(airports_df.shape)

airports_df.head(5)
# Out:
# (7698, 4)
#                                   Airport Name Airport Country Code  Latitude  \
# 0                               Goroka Airport     Papua New Guinea -6.081690
# 1                               Madang Airport     Papua New Guinea -5.207080
# 2                 Mount Hagen Kagamuga Airport     Papua New Guinea -5.826790
# 3                               Nadzab Airport     Papua New Guinea -6.569803
# 4  Port Moresby Jacksons International Airport     Papua New Guinea -9.443380
#
#     Longitude
# 0  145.391998
# 1  145.789001
# 2  144.296005
# 3  146.725977
# 4  147.220001

# %% [markdown]
# # Merging
#
# To merge,
# - first check for unmatching airport names.
# - merge on left and right with left join

# %%
non_matching_airports = set(data["Airport Name"]) - set(airports_df["Airport Name"])
if non_matching_airports:
    print("Airport names in current data that dont match:")
    print(non_matching_airports)
    print(len(non_matching_airports))
else:
    print("All airport names match")
# Out:
# Airport names in current data that dont match:
# {'Tinak Airport', 'Qeshm International Airport', 'Errol Airport', 'Nyac Airport', 'Grant Co Regional/Ogilvie Field', 'Monto Airport', 'Boku Airport', 'Ubari Airport', 'Catalão Airport', 'Deer Park Airport', 'Atmautluak Airport', 'Mulege Airport', 'Mount Full Stop Airport', 'Petit Jean Park Airport', 'Sila Airport', 'Wexford County Airport', 'Aeropuerto "General Tomas de Heres". Ciudad Bolivar', 'Pumani Airport', 'Holbrook Municipal Airport', 'Santa Cruz do Sul Airport', 'Gilgal Airport', 'Amahai Airport', 'Mount Cavenagh Airport', 'Gardner Municipal Airport', 'Wiscasset Airport', 'Gordil Airport', 'Leme Airport', 'Gamba Airport', 'Shay Gap Airport', 'Ponta do Ouro Airport', 'Barra do Corda Airport', 'Slayton Municipal Airport', 'Perry Island Seaplane Base', 'Upiara Airport', 'Yedinka Airport', 'Loen Airport', 'Antônio Guerreiro Airport', 'Mombaça Airport', 'Palo Verde Airport', 'Masalembo Airport', 'Anthony Lagoon Airport', 'Dorado Beach Airport', 'Mara Lodges Airport', 'Mindik Airport', 'Andre Maggi Airport', 'Garowe Airport', 'Tarbela Dam Airport', 'Ferkessedougou Airport', 'Macagua Airport', 'Capital International Airport', 'Lumid Pau Airport', 'Flushing Airport', 'West Memphis Municipal Airport', 'Bazaruto Island Airport', 'Louis Trichardt Airport', 'Phifer Airfield', 'Maramag Airport', 'Lugh Ganane Airport', 'Kamberatoro Airport', 'Virgil I Grissom Municipal Airport', 'Beira Lake Seaplane Base', 'Welshpool Airport', 'Carmel Valley', 'Kambuaya Airport', 'Silgadi Doti Airport', 'Pamol Airport', 'Gascoyne Junction Airport', 'Guthrie-Edmond Regional Airport', 'Cananea National Airport', 'Mulka Airport', 'Pinheiro Airport', 'Andulo Airport', 'Pitts Town Airport', 'Grande Cache Airport', 'Mamfe Airport', 'Compton Woodley Airport', 'Bakkafjörður Airport', 'Dianópolis Airport', 'Whiteside County Airport-Joseph H Bittorf Field', 'West Angelas Airport', 'Naoro Airport', 'Lawrenceville Brunswick Municipal Airport', 'Nissan Island Airport', 'Edna Bay Seaplane Base', 'Cram Field', 'Aumo Airport', 'Abreojos Airport', 'Inyati Airport', 'Morichal Airport', 'Misratah Airport', 'Savuti Airport', 'Sialum Airport', 'Manaung Airport', 'Tarfaya Airport', 'San Ignacio de Moxos Airport', 'Kakoro(Koroko) Airstrip', 'Bokoro Airport', 'Mitzic Airport', 'Biniguni Airport', 'Baibara Airport', 'Morehead Airport', 'Majkin Airport', 'Lučenec Airport', 'Mangunjaya Airport', 'Kololo Airstrip', 'Bowers Field', 'Lowai Airport', 'Kelanoa Airport', 'Fresno Chandler Executive Airport', 'Cambridge Dorchester Airport', 'Lac Gagnon Seaplane Base', 'Luzamba Airport', 'Khaneh Airport', 'Montgomery-Gibbs Executive Airport', 'Benguera Island Airport', 'Downtown Airpark', 'Aragarças Airport', 'San Domino Island Heliport', 'Thaba Nchu Tar Airport', 'Stockholm Airport', 'Marawaka Airport', 'Contadora Airport', 'Marshall Memorial Municipal Airport', 'Solwesi Airport', 'Haelogo Airport', 'Seguela Airport', 'Tororo Airport', 'Manetai Airport', 'Erume Airport', 'Kaikohe Airport', 'Lençóis Paulista Airport', 'Blue Canyon Nyack Airport', 'Sur Airport', 'Ware Airport', 'Gamboa Airport', 'Beagle Bay Airport', 'Chignik Bay Seaplane Base', 'Yucca Airstrip', 'Mountain Airport', 'Port Simpson Seaplane Base', 'Langtang Airport', 'Kuri Airport', 'Canton Municipal Airport', 'Gnarowein Airport', 'Gounda Airport', 'Stevens Village Airport', 'Mubatuba Airport', 'Ivanof Bay Seaplane Base', 'RAF Greenham Common', 'Sungai Pakning Bengkalis Airport', 'Punta Colorada Airport', 'Rockwood Municipal Airport', 'Karimui Airport', 'North Texas Regional Airport/Perrin Field', 'W. H. Bramble Airport', 'Loring International Airport', 'South Molle Island Helipad', 'Captain João Busse Airport', 'Kairuku Airport', 'Sopu Airport', 'Ituberá Airport', 'Chilas Airport', 'Feramin Airport', 'Sekakes Airport', 'Tasu Water Aerodrome', 'El Troncal Airport', 'Council Airport', 'Ellisras Matimba Airport', 'Kasonombe Airport', 'Snap Lake Airport', 'Bazhong Enyang Airport', 'Sinak Airport', 'Middleton Island Airport' ...
# 3049

# %%
# merge on airport names that do match
merged_data = pd.merge(data, airports_df, on="Airport Name", how="left")
merged_data
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 99438         58454      Gareth    Mugford    Male   85       China
# 99439         22028       Kasey   Benedict  Female   19      Russia
# 99440         61732      Darrin     Lucken    Male   65   Indonesia
# 99441         19819       Gayle  Lievesley  Female   34       China
# 99442         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code_x        Country Name  \
# 0                 Coldfoot Airport                     US       United States
# 1                Kugluktuk Airport                     CA              Canada
# 2           Grenoble-Isère Airport                     FR              France
# 3        Ottawa / Gatineau Airport                     CA              Canada
# 4                  Gillespie Field                     US       United States
# ...                            ...                    ...                 ...
# 99438               Hasvik Airport                     NO              Norway
# 99439          Ampampamena Airport                     MG          Madagascar
# 99440  Albacete-Los Llanos Airport                     ES               Spain
# 99441               Gagnoa Airport                     CI       Côte d'Ivoire
# 99442          Yoshkar-Ola Airport                     RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 99438                EU         Europe     12/11/2022             HAA
# 99439                AF         Africa     10/30/2022             IVA
# 99440                EU         Europe      9/10/2022             ABC
# 99441                AF         Africa     10/26/2022             GGN
# 99442                EU         Europe      4/16/2022             JOK
#
#               Pilot Name Flight Status Airport Country Code_y   Latitude  \
# 0          Edithe Leggis       On Time                    NaN        NaN
# 1            Elwood Catt       On Time                 Canada  67.816704
# 2          Darby Felgate       On Time                 France  45.362900
# 3          Dominica Pyle       Delayed                 Canada  45.521702
# 4            Bay Pencost       On Time          United States  32.826199
# ...                  ...           ...                    ...        ...
# 99438     Gareth Mugford     Cancelled                 Norway  70.486702
# 99439     Kasey Benedict     Cancelled             Madagascar -13.484816
# 99440      Darrin Lucken       On Time                  Spain  38.948502
# 99441    Gayle Lievesley     Cancelled                    NaN        NaN
# 99442  Wilhelmine Touret       Delayed                 Russia  56.700600
#
#         Longitude
# 0             NaN
# 1     -115.143997
# 2        5.329370
# 3      -75.563599
# 4     -116.972000
# ...           ...
# 99438   22.139700
# 99439   48.632702
# 99440   -1.863520
# 99441         NaN
# 99442   47.904701
#
# [99443 rows x 18 columns]

# %% [markdown]
# # Cleaning Merged Data
#
# Now that the data has been merged, there are almost 100,000 rows of data so we need to clean up any locations that dont have Longitude or Latitude

# %%
merged_data = merged_data.dropna(subset=["Latitude", "Longitude"])
merged_data
# Out:
#        Passenger ID  First Name Last Name  Gender  Age Nationality  \
# 1             43872      Elwood      Catt    Male   62   Nicaragua
# 2             42633       Darby   Felgate    Male   67      Russia
# 3             78493    Dominica      Pyle  Female   71       China
# 4             82072         Bay   Pencost    Male   21       China
# 5             39630        Lora   Durbann  Female   55      Brazil
# ...             ...         ...       ...     ...  ...         ...
# 99433         70741     Olimpia   Arstall  Female   22       China
# 99438         58454      Gareth   Mugford    Male   85       China
# 99439         22028       Kasey  Benedict  Female   19      Russia
# 99440         61732      Darrin    Lucken    Male   65   Indonesia
# 99442         14485  Wilhelmine    Touret  Female   10      Poland
#
#                             Airport Name Airport Country Code_x  \
# 1                      Kugluktuk Airport                     CA
# 2                 Grenoble-Isère Airport                     FR
# 3              Ottawa / Gatineau Airport                     CA
# 4                        Gillespie Field                     US
# 5      Coronel Horácio de Mattos Airport                     BR
# ...                                  ...                    ...
# 99433        Wuzhou Changzhoudao Airport                     CN
# 99438                     Hasvik Airport                     NO
# 99439                Ampampamena Airport                     MG
# 99440        Albacete-Los Llanos Airport                     ES
# 99442                Yoshkar-Ola Airport                     RU
#
#              Country Name Airport Continent     Continents Departure Date  \
# 1                  Canada               NAM  North America     12/26/2022
# 2                  France                EU         Europe      1/18/2022
# 3                  Canada               NAM  North America      9/16/2022
# 4           United States               NAM  North America      2/25/2022
# 5                  Brazil               SAM  South America      6/10/2022
# ...                   ...               ...            ...            ...
# 99433               China                AS           Asia      4/23/2022
# 99438              Norway                EU         Europe     12/11/2022
# 99439          Madagascar                AF         Africa     10/30/2022
# 99440               Spain                EU         Europe      9/10/2022
# 99442  Russian Federation                EU         Europe      4/16/2022
#
#       Arrival Airport         Pilot Name Flight Status Airport Country Code_y  \
# 1                 YCO        Elwood Catt       On Time                 Canada
# 2                 GNB      Darby Felgate       On Time                 France
# 3                 YND      Dominica Pyle       Delayed                 Canada
# 4                 SEE        Bay Pencost       On Time          United States
# 5                 LEC       Lora Durbann       On Time                 Brazil
# ...               ...                ...           ...                    ...
# 99433             WUZ    Olimpia Arstall       On Time                  China
# 99438             HAA     Gareth Mugford     Cancelled                 Norway
# 99439             IVA     Kasey Benedict     Cancelled             Madagascar
# 99440             ABC      Darrin Lucken       On Time                  Spain
# 99442             JOK  Wilhelmine Touret       Delayed                 Russia
#
#         Latitude   Longitude
# 1      67.816704 -115.143997
# 2      45.362900    5.329370
# 3      45.521702  -75.563599
# 4      32.826199 -116.972000
# 5     -12.482300  -41.277000
# ...          ...         ...
# 99433  23.456699  111.248001
# 99438  70.486702   22.139700
# 99439 -13.484816   48.632702
# 99440  38.948502   -1.863520
# 99442  56.700600   47.904701
#
# [66418 rows x 18 columns]
